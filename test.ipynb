# %%
import os
from dotenv import load_dotenv

# .env 파일을 읽어서 환경변수로 설정
load_dotenv()
# Out:
# True

# %%
value = os.getenv('OPENAI_API_KEY')
value
# Out:
# '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'
